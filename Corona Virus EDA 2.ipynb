# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import random
import matplotlib.colors as mcolors

# %%
data = pd.read_csv("C:/Users/hp/Corono Virus/2019_nCoV_20200121_20200129clean.csv")
data
# Out:
#      Province/State  Country/Region      Last Update  Confirmed  Suspected  \
# 0             Hubei  Mainland China  1/29/2020 21:00     4586.0        0.0
# 1          Zhejiang  Mainland China  1/29/2020 21:00      428.0        0.0
# 2         Guangdong  Mainland China  1/29/2020 21:00      311.0        0.0
# 3             Henan  Mainland China  1/29/2020 21:00      278.0        0.0
# 4             Hunan  Mainland China  1/29/2020 21:00      277.0        0.0
# 5             Anhui  Mainland China  1/29/2020 21:00      200.0        0.0
# 6         Chongqing  Mainland China  1/29/2020 21:00      165.0        0.0
# 7           Jiangxi  Mainland China  1/29/2020 21:00      162.0        0.0
# 8          Shandong  Mainland China  1/29/2020 21:00      145.0        0.0
# 9           Sichuan  Mainland China  1/29/2020 21:00      142.0        0.0
# 10          Jiangsu  Mainland China  1/29/2020 21:00      129.0        0.0
# ...

# %% [markdown]
#     Province/State - City of virus suspected cases.
#     Country/Region - Country of virus suspected cases.
#     last update - Date of update of patient infected
#     Confirmed - Confirmation by doctors that this       patient is infected with deadly virus
#     Suspected - Number of cases registered
#     Recovered - Recovery of the patient
#     Deaths - Death of the patient .

# %%
data = data[data['Country/Region'] == 'Mainland China']

# %%
unique_provinces = data['Province/State'][data.Confirmed >0 ].unique()

# %% [markdown]
# ### Confirm Cases againt Provinces

# %%
for i in range(len(unique_provinces)):
    print (f'{unique_provinces[i]}: {province_confirmed_cases[i]} cases')
# Out:
# Hubei: 34355.0 cases
# Zhejiang: 2679.0 cases
# Guangdong: 2665.0 cases
# Henan: 2043.0 cases
# Hunan: 1912.0 cases
# Anhui: 1422.0 cases
# Chongqing: 1670.0 cases
# Jiangxi: 1054.0 cases
# Shandong: 1182.0 cases
# Sichuan: 1132.0 cases
# Jiangsu: 901.0 cases
# Beijing: 1210.0 cases
# Shanghai: 950.0 cases
# Fujian: 822.0 cases
# Guangxi: 701.0 cases
# Hebei: 410.0 cases
# Shaanxi: 511.0 cases
# Yunnan: 448.0 cases
# Hainan: 475.0 cases
# Heilongjiang: 373.0 cases
# Liaoning: 410.0 cases
# Shanxi: 256.0 cases
# Tianjin: 304.0 cases
# Gansu: 225.0 cases
# Inner Mongolia: 163.0 cases
# Jilin: 104.0 cases
# Xinjiang: 113.0 cases
# Guizhou: 115.0 cases
# Ningxia: 114.0 cases
# Qinghai: 59.0 cases
# Tibet: 1.0 cases

# %%
province_confirmed_cases = []
for i in unique_provinces:
    province_confirmed_cases.append(data[data.Confirmed > 0 ][data['Province/State'] == i].Confirmed.sum())
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
c = random.choices(list(mcolors.CSS4_COLORS.values()),k = len(unique_provinces))
plt.figure(figsize=(15,15))
plt.pie(province_confirmed_cases, colors = c)
plt.legend(unique_provinces, loc='best')
plt.show()

# %%
import datetime 

data['Last Update'] = pd.to_datetime(data['Last Update']) 
data['Date'] = [datetime.datetime.date(d) for d in data ['Last Update']]
data['Time'] = [datetime.datetime.time(d) for d in data['Last Update']]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data['Date'] = data['Date'].astype(str)
day = data["Date"].values
day = [my_str.split("-")[2] for my_str in day]
data["Date"] = day
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data = data.drop(['Last Update'], axis=1)

# %%
data.head()
# Out:
#   Province/State  Country/Region  Confirmed  Suspected  Recovered  Death Date  \
# 0          Hubei  Mainland China     4586.0        0.0       90.0  162.0   29
# 1       Zhejiang  Mainland China      428.0        0.0        4.0    0.0   29
# 2      Guangdong  Mainland China      311.0        0.0        6.0    0.0   29
# 3          Henan  Mainland China      278.0        0.0        2.0    2.0   29
# 4          Hunan  Mainland China      277.0        0.0        0.0    0.0   29
#
#        Time
# 0  21:00:00
# 1  21:00:00
# 2  21:00:00
# 3  21:00:00
# 4  21:00:00

# %%
unique_dates = data['Date'].unique()
unique_dates.sort()
unique_dates
# Out:
# array(['21', '22', '23', '24', '25', '26', '27', '28', '29'], dtype=object)

# %%
Death = data['Death'] > 0

# %% [markdown]
# ### Confirm cases

# %%
china_cases = []

for i in unique_dates:
    china_cases.append(data[data['Date']==i].Confirmed.sum())

    plt.figure(figsize=(15, 10));
plt.plot(unique_dates, china_cases);
plt.title('No of Coronavirus Cases Over Days', size=15);
plt.xlabel('Days', size=15)
plt.ylabel('No of Cases', size=15);
plt.show();

# %% [markdown]
# ### No of Deaths

# %%
china_cases = []

for i in unique_dates:
    china_cases.append(data[data['Date']==i].Death.sum())

    plt.figure(figsize=(15, 10));
plt.plot(unique_dates, china_cases);
plt.title('Death cases', size=15);
plt.xlabel('Days', size=15)
plt.ylabel('No of Deaths', size=15);
plt.show();

# %% [markdown]
# ### Deaths in different provinces

# %%
province_Death_cases = []
for i in unique_provinces:
    province_Death_cases.append(data[data.Death>0][data['Province/State']==i].Death.sum())
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
c = random.sample(list(mcolors.CSS4_COLORS.values()),k = len(unique_provinces))
plt.figure(figsize=(15,15))
plt.pie(province_Death_cases, colors = c)
plt.legend(unique_provinces, loc='best')
plt.show()
